# %%
def add(a, b):
    return a + b

# %%
add(2, 3) # this will return 5 (because 3+2 = 5)

# %%
def sum_list(values):
    total = 0
    for i in values:
        sum2 = add(total, i)
        total = sum2
    print(sum2)
    return(sum2)

# %%
values = [1, 2, 3, 8]
sum_list(values)
